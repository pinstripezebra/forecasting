# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
from utility.data_query import return_surrounding_weather
#df1 = pd.read_csv("C:/Users/seelc/OneDrive/Desktop/Lucas Desktop Items/Projects/forecasting/app_development/Data/weather_data.csv")

# %%
df1 = return_surrounding_weather(37.7749, -122.4194, margin = 0.1)
df1.head()
# Out:
#                   temperature_2m  cloudcover  windspeed_10m  latitude  \
# time
# 2024-11-30T00:00            13.5          76            6.6   37.7749
# 2024-11-30T01:00            12.1          78            6.5   37.7749
# 2024-11-30T02:00            10.6          36            4.7   37.7749
# 2024-11-30T03:00            10.0           8            5.3   37.7749
# 2024-11-30T04:00             9.2           2            8.3   37.7749
#
#                   longitude              location
# time
# 2024-11-30T00:00  -122.4194  (37.7749, -122.4194)
# 2024-11-30T01:00  -122.4194  (37.7749, -122.4194)
# 2024-11-30T02:00  -122.4194  (37.7749, -122.4194)
# 2024-11-30T03:00  -122.4194  (37.7749, -122.4194)
# 2024-11-30T04:00  -122.4194  (37.7749, -122.4194)

# %%
fig = go.Figure(go.Densitymap(lat=df1.latitude, lon=df1.longitude, z=df1.cloudcover,
                                 radius=20))
fig.update_layout(map_style="open-street-map", map_center_lon=180)
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %%
df1 = df1.reset_index()
df1.head(10)
# Out:
#                time  temperature_2m  cloudcover  windspeed_10m  latitude  \
# 0  2024-11-30T00:00            13.5          76            6.6   37.7749
# 1  2024-11-30T01:00            12.1          78            6.5   37.7749
# 2  2024-11-30T02:00            10.6          36            4.7   37.7749
# 3  2024-11-30T03:00            10.0           8            5.3   37.7749
# 4  2024-11-30T04:00             9.2           2            8.3   37.7749
# 5  2024-11-30T05:00             8.8           0            1.9   37.7749
# 6  2024-11-30T06:00             7.4           4            9.0   37.7749
# 7  2024-11-30T07:00             6.3           1           10.8   37.7749
# 8  2024-11-30T08:00             6.8           0           13.3   37.7749
# 9  2024-11-30T09:00             6.9           7            4.1   37.7749
#
#    longitude              location
# 0  -122.4194  (37.7749, -122.4194)
# 1  -122.4194  (37.7749, -122.4194)
# 2  -122.4194  (37.7749, -122.4194)
# ...

# %%
df1 = df1.sort_values(by = 'time').reset_index(drop=True)
df1.head()
# Out:
#                time  temperature_2m  cloudcover  windspeed_10m  latitude  \
# 0  2024-11-30T00:00            13.5          76            6.6   37.7749
# 1  2024-11-30T00:00            14.4          69            1.5   37.7749
# 2  2024-11-30T00:00            14.5          82           12.0   37.6749
# 3  2024-11-30T00:00            12.7          77            6.0   37.6749
# 4  2024-11-30T00:00            14.4          68           16.7   37.7749
#
#    longitude                        location
# 0  -122.4194            (37.7749, -122.4194)
# 1  -122.3194            (37.7749, -122.3194)
# 2  -122.5194  (37.6749, -122.51939999999999)
# 3  -122.4194            (37.6749, -122.4194)
# 4  -122.5194  (37.7749, -122.51939999999999)

# %%
print(df1['location'].drop_duplicates())
# Out:
# 0                            (37.7749, -122.4194)
# 168                          (37.7749, -122.3194)
# 336                (37.7749, -122.51939999999999)
# 504               (37.874900000000004, -122.4194)
# 672               (37.874900000000004, -122.3194)
# 840     (37.874900000000004, -122.51939999999999)
# 1008                         (37.6749, -122.4194)
# 1176                         (37.6749, -122.3194)
# 1344               (37.6749, -122.51939999999999)
# Name: location, dtype: object

# %%
fig = px.density_mapbox(df1.sort_values(by = 'time'), 
                        radius=100,
                        opacity=0.7,
                        lat=df1.latitude, 
                        lon = df1.longitude, 
                        z = df1.temperature_2m,
                        hover_data='temperature_2m',
                        animation_frame='time',
                        zoom=9, 
                        mapbox_style="open-street-map")
fig.update_layout(height = 800, width = 900)
fig.show()
